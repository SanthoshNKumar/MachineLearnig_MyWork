# %%
# Stochastic Gradient Descent : Parameters are updated after computing the gradient of error with respect to a single training 
#                               example

# %%
import numpy as np
from numpy import random
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

x = [30, 35, 37, 59, 70, 76, 88, 100]
y = [1100, 1423, 1377, 1800, 2304, 2588, 3495, 4839]

x = np.reshape(x,(-1,1))
y = np.reshape(y,(-1,1))

scaler = MinMaxScaler()
scaler.fit(x)
x = scaler.transform(x)

#scaler.fit(y)
#y = scaler.transform(y

# %%
theta0 =0
theta1 =0

learningrate = 0.1

loss = []
epochs = []

# %%
for steps in range(100):
    
    seed = np.random.random()
    np.random.seed(int(seed))
    np.random.shuffle(x)
    np.random.seed(int(seed))
    np.random.shuffle(y)
    
    for i in range(0,1):
        print("i =",i)

        predicted = theta0 + (x[i] * theta1)
        print("predicted:=",predicted)

        cost = np.square(np.subtract(y[i],predicted)) / 2
        print("cost:=",cost)
        
        loss.append(cost)
        epochs.append(steps)

        dtheta0 = -1 * (y[i] - predicted)
        dtheta1 = (-x[i]) * (y[i] - predicted)

        theta0 = theta0 - learningrate * dtheta0
        theta1 = theta1 - learningrate * dtheta1
# Out:
# i = 0
# predicted:= [0.]
# cost:= [6107512.5]
# i = 0
# predicted:= [539.79918367]
# cost:= [2097563.29200033]
# i = 0
# predicted:= [554.32008163]
# cost:= [148883.2866547]
# i = 0
# predicted:= [960.3529669]
# cost:= [3212217.7912086]
# i = 0
# predicted:= [1279.10974028]
# cost:= [856596.85599095]
# i = 0
# predicted:= [993.24180275]
# cost:= [5698.65633989]
# i = 0
# predicted:= [1600.66153289]
# cost:= [1794259.11398759]
# i = 0
# predicted:= [1769.77591881]
# cost:= [334745.32352019]
# i = 0
# predicted:= [1275.17387731]
# cost:= [15342.94364527]
# i = 0
# predicted:= [2029.00400105]
# cost:= [1074572.1344693]
# i = 0
# predicted:= [2095.83644687]
# cost:= [121112.48151563]
# i = 0
# predicted:= [1453.47244478]
# cost:= [62471.38461077]
# i = 0
# predicted:= [2316.91562811]
# cost:= [693941.39364511]
# i = 0
# predicted:= [2312.91291699]
# cost:= [37836.45162046]
# i = 0
# predicted:= [1563.4423458]
# cost:= [107389.40393838]
# i = 0
# predicted:= [2511.7458485]
# ...
