# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# Load datasets
wine = load_wine()

print(wine.feature_names)
print(wine.target_names)

# Split Dataset into training and Testing
X_train,X_test,y_train,y_test = train_test_split(wine.data,wine.target,test_size=0.3)

scores = {}
score_list = []

k_range = range(1,26)

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    y_pred = knn.predict(X_test)
    scores[k] = metrics.accuracy_score(y_test,y_pred)
    score_list.append(metrics.accuracy_score(y_test,y_pred))
    print("Accuracy is ", metrics.accuracy_score(y_test,y_pred)*100,"% for K-Value:",k)
    
plt.plot(k_range,score_list)
plt.xlabel("Value of K for KNN")
plt.ylabel("Testing Accuracy")
# Out:
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# ['class_0' 'class_1' 'class_2']
# Accuracy is  74.07407407407408 % for K-Value: 1
# Accuracy is  66.66666666666666 % for K-Value: 2
# Accuracy is  61.111111111111114 % for K-Value: 3
# Accuracy is  61.111111111111114 % for K-Value: 4
# Accuracy is  61.111111111111114 % for K-Value: 5
# Accuracy is  64.81481481481481 % for K-Value: 6
# Accuracy is  64.81481481481481 % for K-Value: 7
# Accuracy is  64.81481481481481 % for K-Value: 8
# Accuracy is  68.51851851851852 % for K-Value: 9
# Accuracy is  66.66666666666666 % for K-Value: 10
# Accuracy is  64.81481481481481 % for K-Value: 11
# Accuracy is  64.81481481481481 % for K-Value: 12
# Accuracy is  61.111111111111114 % for K-Value: 13
# Accuracy is  66.66666666666666 % for K-Value: 14
# Accuracy is  66.66666666666666 % for K-Value: 15
# Accuracy is  70.37037037037037 % for K-Value: 16
# Accuracy is  68.51851851851852 % for K-Value: 17
# Accuracy is  68.51851851851852 % for K-Value: 18
# Accuracy is  64.81481481481481 % for K-Value: 19
# Accuracy is  68.51851851851852 % for K-Value: 20
# Accuracy is  68.51851851851852 % for K-Value: 21
# Accuracy is  64.81481481481481 % for K-Value: 22
# Accuracy is  62.96296296296296 % for K-Value: 23
# Accuracy is  64.81481481481481 % for K-Value: 24
# Accuracy is  66.66666666666666 % for K-Value: 25
# Text(0, 0.5, 'Testing Accuracy')
