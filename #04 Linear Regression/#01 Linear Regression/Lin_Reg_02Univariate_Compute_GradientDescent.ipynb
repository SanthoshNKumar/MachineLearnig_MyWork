# %%
import numpy as np

def gradientDescent(x,y):    
    theta0=theta1 = 0
    iteration = 10
    n = len(x)
    learning_rate = 0.08
    print("***************************")
    print("Define Initial values:")
    print("Total Iteration",iteration)
    print("theta0 =",theta0)
    print("theta1 =",theta1)
    print("Learning rate =",learning_rate)
    print("n =",n)
    print("***************************")
    
    for i in range(iteration):
        print("Iteration = ",i)
        print("Step 1: Calculate the y_prediction")
        print("y_predicted = theta0 + theta1 * x")
        print("'''''''''''''")
        print("theta0 =", theta0)
        print("theta1 =", theta1)
        print("x =",x)
        print("theta0 + theta1 * x = ",theta0 + theta1 * x)
        y_predicted = theta0 + theta1 * x
        
        
        print("y_predicted = ",y_predicted)
    
        print("'''''''''''''")
    
        print("Step 2:Calculate Cost function")
        print("Cost= (1/n)Σ(y - y_predicted)²")
        
        print("'''''''''''''")
        print("y=",y)
        print("y_predicted = ",y_predicted)
        print("1. (y - y_predicted)²= ",[val**2 for val in (y-y_predicted)])
        print("2. Σ(y - y_predicted)² = ",sum([val**2 for val in (y-y_predicted)]))
        cost = (1/n)* sum([val**2 for val in (y-y_predicted)])
        print("3. (1/n)Σ(y - y_predicted)² = ",cost)
        print("Cost = ",cost)
        
        print("'''''''''''''")
        
        print("Step 3:Finding Gradient Descent")
        
        print("theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))")
        print("theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))")
        print("\n")
        
        print("Finding theta0")
        print("theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))")
        print("y =",y)
        print("y_predicted =",y_predicted)
        print("n =",n)
        print("\n")
        print("1. (y-y_predicted)) = ",y-y_predicted)
        print("2. sum(y-y_predicted)) = ",sum(y-y_predicted))
        print("3. (-(2/n)*sum(y-y_predicted))=",(-(2/n)*sum(y-y_predicted)))
        print("4. theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))")
        theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
        print("5. theta0 = ",theta0)
        
        print("\n")
        
        print("Finding theta1")
        print("theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))")
        print("x =",x)
        print("y =",y)
        print("y_predicted =",y_predicted)
        print("n =",n)
        print("1. (y-y_predicted)) = ",y-y_predicted)
        print("2. x*(y-y_predicted)) = ",x*(y-y_predicted))
        print("3. sum(x*(y-y_predicted))) = ",sum(x*(y-y_predicted)))
        print("4. (-(2/n)*sum(x*(y-y_predicted))=",(-(2/n)*sum(x*(y-y_predicted))))
        
        theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
        
        
        print("theta1 = ",theta1)
       
        print("##########################################################################################")    
        print("\n")

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradientDescent(x,y)
# Out:
# ***************************
# Define Initial values:
# Total Iteration 10
# theta0 = 0
# theta1 = 0
# Learning rate = 0.08
# n = 5
# ***************************
# Iteration =  0
# Step 1: Calculate the y_prediction
# y_predicted = theta0 + theta1 * x
# '''''''''''''
# theta0 = 0
# theta1 = 0
# x = [1 2 3 4 5]
# theta0 + theta1 * x =  [0 0 0 0 0]
# y_predicted =  [0 0 0 0 0]
# '''''''''''''
# Step 2:Calculate Cost function
# Cost= (1/n)Σ(y - y_predicted)²
# '''''''''''''
# y= [ 5  7  9 11 13]
# y_predicted =  [0 0 0 0 0]
# 1. (y - y_predicted)²=  [25, 49, 81, 121, 169]
# 2. Σ(y - y_predicted)² =  445
# 3. (1/n)Σ(y - y_predicted)² =  89.0
# Cost =  89.0
# '''''''''''''
# Step 3:Finding Gradient Descent
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
#
#
# Finding theta0
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# y = [ 5  7  9 11 13]
# y_predicted = [0 0 0 0 0]
# n = 5
#
#
# 1. (y-y_predicted)) =  [ 5  7  9 11 13]
# 2. sum(y-y_predicted)) =  45
# 3. (-(2/n)*sum(y-y_predicted))= -18.0
# 4. theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# 5. theta0 =  1.44
#
#
# Finding theta1
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
# x = [1 2 3 4 5]
# y = [ 5  7  9 11 13]
# y_predicted = [0 0 0 0 0]
# n = 5
# 1. (y-y_predicted)) =  [ 5  7  9 11 13]
# 2. x*(y-y_predicted)) =  [ 5 14 27 44 65]
# 3. sum(x*(y-y_predicted))) =  155
# 4. (-(2/n)*sum(x*(y-y_predicted))= -62.0
# theta1 =  4.96
# ##########################################################################################
#
#
# Iteration =  1
# Step 1: Calculate the y_prediction
# y_predicted = theta0 + theta1 * x
# '''''''''''''
# theta0 = 1.44
# theta1 = 4.96
# x = [1 2 3 4 5]
# theta0 + theta1 * x =  [ 6.4  11.36 16.32 21.28 26.24]
# y_predicted =  [ 6.4  11.36 16.32 21.28 26.24]
# '''''''''''''
# Step 2:Calculate Cost function
# Cost= (1/n)Σ(y - y_predicted)²
# '''''''''''''
# y= [ 5  7  9 11 13]
# y_predicted =  [ 6.4  11.36 16.32 21.28 26.24]
# 1. (y - y_predicted)²=  [1.960000000000001, 19.009599999999995, 53.58240000000001, 105.67840000000002, 175.29760000000005]
# 2. Σ(y - y_predicted)² =  355.5280000000001
# 3. (1/n)Σ(y - y_predicted)² =  71.10560000000002
# Cost =  71.10560000000002
# '''''''''''''
# Step 3:Finding Gradient Descent
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
#
#
# Finding theta0
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# y = [ 5  7  9 11 13]
# y_predicted = [ 6.4  11.36 16.32 21.28 26.24]
# n = 5
#
#
# 1. (y-y_predicted)) =  [ -1.4   -4.36  -7.32 -10.28 -13.24]
# 2. sum(y-y_predicted)) =  -36.6
# 3. (-(2/n)*sum(y-y_predicted))= 14.64
# 4. theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# 5. theta0 =  0.26879999999999993
#
#
# Finding theta1
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
# x = [1 2 3 4 5]
# y = [ 5  7  9 11 13]
# y_predicted = [ 6.4  11.36 16.32 21.28 26.24]
# n = 5
# 1. (y-y_predicted)) =  [ -1.4   -4.36  -7.32 -10.28 -13.24]
# 2. x*(y-y_predicted)) =  [ -1.4   -8.72 -21.96 -41.12 -66.2 ]
# 3. sum(x*(y-y_predicted))) =  -139.40000000000003
# 4. (-(2/n)*sum(x*(y-y_predicted))= 55.76000000000002
# theta1 =  0.4991999999999983
# ##########################################################################################
#
#
# Iteration =  2
# Step 1: Calculate the y_prediction
# y_predicted = theta0 + theta1 * x
# '''''''''''''
# theta0 = 0.26879999999999993
# theta1 = 0.4991999999999983
# x = [1 2 3 4 5]
# theta0 + theta1 * x =  [0.768  1.2672 1.7664 2.2656 2.7648]
# y_predicted =  [0.768  1.2672 1.7664 2.2656 2.7648]
# '''''''''''''
# Step 2:Calculate Cost function
# Cost= (1/n)Σ(y - y_predicted)²
# '''''''''''''
# y= [ 5  7  9 11 13]
# y_predicted =  [0.768  1.2672 1.7664 2.2656 2.7648]
# 1. (y - y_predicted)²=  [17.909824000000018, 32.86499584000004, 52.32496896000008, 76.28974336000014, 104.7593190400002]
# 2. Σ(y - y_predicted)² =  284.1488512000005
# 3. (1/n)Σ(y - y_predicted)² =  56.8297702400001
# Cost =  56.8297702400001
# '''''''''''''
# Step 3:Finding Gradient Descent
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
#
#
# Finding theta0
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# y = [ 5  7  9 11 13]
# y_predicted = [0.768  1.2672 1.7664 2.2656 2.7648]
# n = 5
#
#
# 1. (y-y_predicted)) =  [ 4.232   5.7328  7.2336  8.7344 10.2352]
# 2. sum(y-y_predicted)) =  36.16800000000003
# 3. (-(2/n)*sum(y-y_predicted))= -14.467200000000012
# 4. theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# 5. theta0 =  1.426176000000001
#
#
# Finding theta1
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
# x = [1 2 3 4 5]
# y = [ 5  7  9 11 13]
# y_predicted = [0.768  1.2672 1.7664 2.2656 2.7648]
# n = 5
# 1. (y-y_predicted)) =  [ 4.232   5.7328  7.2336  8.7344 10.2352]
# 2. x*(y-y_predicted)) =  [ 4.232  11.4656 21.7008 34.9376 51.176 ]
# 3. sum(x*(y-y_predicted))) =  123.5120000000001
# 4. (-(2/n)*sum(x*(y-y_predicted))= -49.404800000000044
# theta1 =  4.451584000000002
# ##########################################################################################
#
#
# Iteration =  3
# Step 1: Calculate the y_prediction
# y_predicted = theta0 + theta1 * x
# '''''''''''''
# theta0 = 1.426176000000001
# theta1 = 4.451584000000002
# x = [1 2 3 4 5]
# theta0 + theta1 * x =  [ 5.87776  10.329344 14.780928 19.232512 23.684096]
# y_predicted =  [ 5.87776  10.329344 14.780928 19.232512 23.684096]
# '''''''''''''
# Step 2:Calculate Cost function
# Cost= (1/n)Σ(y - y_predicted)²
# '''''''''''''
# y= [ 5  7  9 11 13]
# y_predicted =  [ 5.87776  10.329344 14.780928 19.232512 23.684096]
# 1. (y - y_predicted)²=  [0.7704626176000052, 11.08453147033604, 33.419128541184094, 67.77425383014418, 114.1499073372163]
# 2. Σ(y - y_predicted)² =  227.1982837964806
# 3. (1/n)Σ(y - y_predicted)² =  45.43965675929613
# Cost =  45.43965675929613
# '''''''''''''
# Step 3:Finding Gradient Descent
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
#
#
# Finding theta0
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# y = [ 5  7  9 11 13]
# y_predicted = [ 5.87776  10.329344 14.780928 19.232512 23.684096]
# n = 5
#
#
# 1. (y-y_predicted)) =  [ -0.87776   -3.329344  -5.780928  -8.232512 -10.684096]
# 2. sum(y-y_predicted)) =  -28.904640000000043
# 3. (-(2/n)*sum(y-y_predicted))= 11.561856000000018
# 4. theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# 5. theta0 =  0.5012275199999995
#
#
# Finding theta1
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
# x = [1 2 3 4 5]
# y = [ 5  7  9 11 13]
# y_predicted = [ 5.87776  10.329344 14.780928 19.232512 23.684096]
# n = 5
# 1. (y-y_predicted)) =  [ -0.87776   -3.329344  -5.780928  -8.232512 -10.684096]
# 2. x*(y-y_predicted)) =  [ -0.87776   -6.658688 -17.342784 -32.930048 -53.42048 ]
# 3. sum(x*(y-y_predicted))) =  -111.22976000000014
# 4. (-(2/n)*sum(x*(y-y_predicted))= 44.49190400000006
# theta1 =  0.892231679999997
# ##########################################################################################
#
#
# Iteration =  4
# Step 1: Calculate the y_prediction
# y_predicted = theta0 + theta1 * x
# '''''''''''''
# theta0 = 0.5012275199999995
# theta1 = 0.892231679999997
# x = [1 2 3 4 5]
# theta0 + theta1 * x =  [1.3934592  2.28569088 3.17792256 4.07015424 4.96238592]
# y_predicted =  [1.3934592  2.28569088 3.17792256 4.07015424 4.96238592]
# '''''''''''''
# Step 2:Calculate Cost function
# Cost= (1/n)Σ(y - y_predicted)²
# '''''''''''''
# y= [ 5  7  9 11 13]
# y_predicted =  [1.3934592  2.28569088 3.17792256 4.07015424 4.96238592]
# 1. (y - y_predicted)²=  [13.007136542064664, 22.224710478915235, 33.89658571735707, 48.02276225739015, 64.60324009901449]
# 2. Σ(y - y_predicted)² =  181.7544350947416
# 3. (1/n)Σ(y - y_predicted)² =  36.35088701894832
# Cost =  36.35088701894832
# '''''''''''''
# Step 3:Finding Gradient Descent
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
#
#
# Finding theta0
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# y = [ 5  7  9 11 13]
# y_predicted = [1.3934592  2.28569088 3.17792256 4.07015424 4.96238592]
# n = 5
#
#
# 1. (y-y_predicted)) =  [3.6065408  4.71430912 5.82207744 6.92984576 8.03761408]
# 2. sum(y-y_predicted)) =  29.110387200000048
# 3. (-(2/n)*sum(y-y_predicted))= -11.64415488000002
# 4. theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# 5. theta0 =  1.432759910400001
#
#
# Finding theta1
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
# x = [1 2 3 4 5]
# y = [ 5  7  9 11 13]
# y_predicted = [1.3934592  2.28569088 3.17792256 4.07015424 4.96238592]
# n = 5
# 1. (y-y_predicted)) =  [3.6065408  4.71430912 5.82207744 6.92984576 8.03761408]
# 2. x*(y-y_predicted)) =  [ 3.6065408   9.42861824 17.46623232 27.71938304 40.1880704 ]
# 3. sum(x*(y-y_predicted))) =  98.40884480000017
# 4. (-(2/n)*sum(x*(y-y_predicted))= -39.36353792000007
# theta1 =  4.041314713600002
# ##########################################################################################
#
#
# Iteration =  5
# Step 1: Calculate the y_prediction
# y_predicted = theta0 + theta1 * x
# '''''''''''''
# theta0 = 1.432759910400001
# theta1 = 4.041314713600002
# x = [1 2 3 4 5]
# theta0 + theta1 * x =  [ 5.47407462  9.51538934 13.55670405 17.59801876 21.63933348]
# y_predicted =  [ 5.47407462  9.51538934 13.55670405 17.59801876 21.63933348]
# '''''''''''''
# Step 2:Calculate Cost function
# Cost= (1/n)Σ(y - y_predicted)²
# '''''''''''''
# y= [ 5  7  9 11 13]
# y_predicted =  [ 5.47407462  9.51538934 13.55670405 17.59801876 21.63933348]
# 1. (y - y_predicted)²=  [0.22474674912074474, 6.327183519711795, 20.763551810222562, 43.533851620653046, 74.63808295100324]
# 2. Σ(y - y_predicted)² =  145.4874166507114
# 3. (1/n)Σ(y - y_predicted)² =  29.097483330142282
# Cost =  29.097483330142282
# '''''''''''''
# Step 3:Finding Gradient Descent
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
#
#
# Finding theta0
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# y = [ 5  7  9 11 13]
# y_predicted = [ 5.47407462  9.51538934 13.55670405 17.59801876 21.63933348]
# n = 5
#
#
# 1. (y-y_predicted)) =  [-0.47407462 -2.51538934 -4.55670405 -6.59801876 -8.63933348]
# 2. sum(y-y_predicted)) =  -22.78352025600004
# 3. (-(2/n)*sum(y-y_predicted))= 9.113408102400015
# 4. theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# 5. theta0 =  0.7036872622079998
#
#
# Finding theta1
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
# x = [1 2 3 4 5]
# y = [ 5  7  9 11 13]
# y_predicted = [ 5.47407462  9.51538934 13.55670405 17.59801876 21.63933348]
# n = 5
# 1. (y-y_predicted)) =  [-0.47407462 -2.51538934 -4.55670405 -6.59801876 -8.63933348]
# 2. x*(y-y_predicted)) =  [ -0.47407462  -5.03077868 -13.67011215 -26.39207506 -43.19666739]
# 3. sum(x*(y-y_predicted))) =  -88.76370790400014
# 4. (-(2/n)*sum(x*(y-y_predicted))= 35.50548316160006
# theta1 =  1.2008760606719973
# ##########################################################################################
#
#
# Iteration =  6
# Step 1: Calculate the y_prediction
# y_predicted = theta0 + theta1 * x
# '''''''''''''
# theta0 = 0.7036872622079998
# theta1 = 1.2008760606719973
# x = [1 2 3 4 5]
# theta0 + theta1 * x =  [1.90456332 3.10543938 4.30631544 5.5071915  6.70806757]
# y_predicted =  [1.90456332 3.10543938 4.30631544 5.5071915  6.70806757]
# '''''''''''''
# Step 2:Calculate Cost function
# Cost= (1/n)Σ(y - y_predicted)²
# '''''''''''''
# y= [ 5  7  9 11 13]
# y_predicted =  [1.90456332 3.10543938 4.30631544 5.5071915  6.70806757]
# 1. (y - y_predicted)²=  [9.581728222059725, 15.16760239518787, 22.030674709130228, 30.170945163886792, 39.58841375945757]
# 2. Σ(y - y_predicted)² =  116.53936424972218
# 3. (1/n)Σ(y - y_predicted)² =  23.307872849944438
# Cost =  23.307872849944438
# '''''''''''''
# Step 3:Finding Gradient Descent
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
#
#
# Finding theta0
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# y = [ 5  7  9 11 13]
# y_predicted = [1.90456332 3.10543938 4.30631544 5.5071915  6.70806757]
# n = 5
#
#
# 1. (y-y_predicted)) =  [3.09543668 3.89456062 4.69368456 5.4928085  6.29193243]
# 2. sum(y-y_predicted)) =  23.46842277888004
# 3. (-(2/n)*sum(y-y_predicted))= -9.387369111552017
# 4. theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# 5. theta0 =  1.4546767911321612
#
#
# Finding theta1
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
# x = [1 2 3 4 5]
# y = [ 5  7  9 11 13]
# y_predicted = [1.90456332 3.10543938 4.30631544 5.5071915  6.70806757]
# n = 5
# 1. (y-y_predicted)) =  [3.09543668 3.89456062 4.69368456 5.4928085  6.29193243]
# 2. x*(y-y_predicted)) =  [ 3.09543668  7.78912123 14.08105367 21.97123398 31.45966217]
# 3. sum(x*(y-y_predicted))) =  78.39650772992015
# 4. (-(2/n)*sum(x*(y-y_predicted))= -31.35860309196806
# theta1 =  3.7095643080294423
# ##########################################################################################
#
#
# Iteration =  7
# Step 1: Calculate the y_prediction
# y_predicted = theta0 + theta1 * x
# '''''''''''''
# theta0 = 1.4546767911321612
# theta1 = 3.7095643080294423
# x = [1 2 3 4 5]
# theta0 + theta1 * x =  [ 5.1642411   8.87380541 12.58336972 16.29293402 20.00249833]
# y_predicted =  [ 5.1642411   8.87380541 12.58336972 16.29293402 20.00249833]
# '''''''''''''
# Step 2:Calculate Cost function
# Cost= (1/n)Σ(y - y_predicted)²
# '''''''''''''
# y= [ 5  7  9 11 13]
# y_predicted =  [ 5.1642411   8.87380541 12.58336972 16.29293402 20.00249833]
# 1. (y - y_predicted)²=  [0.026975138653811806, 3.5111467040184023, 12.840538515959365, 28.0151505744767, 49.0349828795704]
# 2. Σ(y - y_predicted)² =  93.42879381267868
# 3. (1/n)Σ(y - y_predicted)² =  18.685758762535738
# Cost =  18.685758762535738
# '''''''''''''
# Step 3:Finding Gradient Descent
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
#
#
# Finding theta0
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# y = [ 5  7  9 11 13]
# y_predicted = [ 5.1642411   8.87380541 12.58336972 16.29293402 20.00249833]
# n = 5
#
#
# 1. (y-y_predicted)) =  [-0.1642411  -1.87380541 -3.58336972 -5.29293402 -7.00249833]
# 2. sum(y-y_predicted)) =  -17.916848576102442
# 3. (-(2/n)*sum(y-y_predicted))= 7.166739430440977
# 4. theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# 5. theta0 =  0.881337636696883
#
#
# Finding theta1
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
# x = [1 2 3 4 5]
# y = [ 5  7  9 11 13]
# y_predicted = [ 5.1642411   8.87380541 12.58336972 16.29293402 20.00249833]
# n = 5
# 1. (y-y_predicted)) =  [-0.1642411  -1.87380541 -3.58336972 -5.29293402 -7.00249833]
# 2. x*(y-y_predicted)) =  [ -0.1642411   -3.74761081 -10.75010915 -21.17173609 -35.01249166]
# 3. sum(x*(y-y_predicted))) =  -70.84618880860174
# 4. (-(2/n)*sum(x*(y-y_predicted))= 28.338475523440696
# theta1 =  1.4424862661541864
# ##########################################################################################
#
#
# Iteration =  8
# Step 1: Calculate the y_prediction
# y_predicted = theta0 + theta1 * x
# '''''''''''''
# theta0 = 0.881337636696883
# theta1 = 1.4424862661541864
# x = [1 2 3 4 5]
# theta0 + theta1 * x =  [2.3238239  3.76631017 5.20879644 6.6512827  8.09376897]
# y_predicted =  [2.3238239  3.76631017 5.20879644 6.6512827  8.09376897]
# '''''''''''''
# Step 2:Calculate Cost function
# Cost= (1/n)Σ(y - y_predicted)²
# '''''''''''''
# y= [ 5  7  9 11 13]
# y_predicted =  [2.3238239  3.76631017 5.20879644 6.6512827  8.09376897]
# 1. (y - y_predicted)²=  [7.161918502951282, 10.456749923078817, 14.373224470059753, 18.911342143894093, 24.07110294458183]
# 2. Σ(y - y_predicted)² =  74.97433798456578
# 3. (1/n)Σ(y - y_predicted)² =  14.994867596913156
# Cost =  14.994867596913156
# '''''''''''''
# Step 3:Finding Gradient Descent
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
#
#
# Finding theta0
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# y = [ 5  7  9 11 13]
# y_predicted = [2.3238239  3.76631017 5.20879644 6.6512827  8.09376897]
# n = 5
#
#
# 1. (y-y_predicted)) =  [2.6761761  3.23368983 3.79120356 4.3487173  4.90623103]
# 2. sum(y-y_predicted)) =  18.95601782420279
# 3. (-(2/n)*sum(y-y_predicted))= -7.5824071296811155
# 4. theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# 5. theta0 =  1.4879302070713722
#
#
# Finding theta1
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
# x = [1 2 3 4 5]
# y = [ 5  7  9 11 13]
# y_predicted = [2.3238239  3.76631017 5.20879644 6.6512827  8.09376897]
# n = 5
# 1. (y-y_predicted)) =  [2.6761761  3.23368983 3.79120356 4.3487173  4.90623103]
# 2. x*(y-y_predicted)) =  [ 2.6761761   6.46737966 11.37361069 17.39486919 24.53115516]
# 3. sum(x*(y-y_predicted))) =  62.4431908110665
# 4. (-(2/n)*sum(x*(y-y_predicted))= -24.9772763244266
# theta1 =  3.4406683721083144
# ##########################################################################################
#
#
# Iteration =  9
# Step 1: Calculate the y_prediction
# y_predicted = theta0 + theta1 * x
# '''''''''''''
# theta0 = 1.4879302070713722
# theta1 = 3.4406683721083144
# x = [1 2 3 4 5]
# theta0 + theta1 * x =  [ 4.92859858  8.36926695 11.80993532 15.2506037  18.69127207]
# y_predicted =  [ 4.92859858  8.36926695 11.80993532 15.2506037  18.69127207]
# '''''''''''''
# Step 2:Calculate Cost function
# Cost= (1/n)Σ(y - y_predicted)²
# '''''''''''''
# y= [ 5  7  9 11 13]
# y_predicted =  [ 4.92859858  8.36926695 11.80993532 15.2506037  18.69127207]
# 1. (y - y_predicted)²=  [0.005098162895159503, 1.8748919838895366, 7.895736521670355, 18.067631776237615, 32.390577747591294]
# 2. Σ(y - y_predicted)² =  60.23393619228396
# 3. (1/n)Σ(y - y_predicted)² =  12.046787238456794
# Cost =  12.046787238456794
# '''''''''''''
# Step 3:Finding Gradient Descent
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
#
#
# Finding theta0
# theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# y = [ 5  7  9 11 13]
# y_predicted = [ 4.92859858  8.36926695 11.80993532 15.2506037  18.69127207]
# n = 5
#
#
# 1. (y-y_predicted)) =  [ 0.07140142 -1.36926695 -2.80993532 -4.2506037  -5.69127207]
# 2. sum(y-y_predicted)) =  -14.049676616981575
# 3. (-(2/n)*sum(y-y_predicted))= 5.619870646792631
# 4. theta0 = theta0 - learning_rate * (-(2/n)*sum(y-y_predicted))
# 5. theta0 =  1.0383405553279617
#
#
# Finding theta1
# theta1 = theta1 - learning_rate * (-(2/n)*sum(x*(y-y_predicted)))
# x = [1 2 3 4 5]
# y = [ 5  7  9 11 13]
# y_predicted = [ 4.92859858  8.36926695 11.80993532 15.2506037  18.69127207]
# n = 5
# 1. (y-y_predicted)) =  [ 0.07140142 -1.36926695 -2.80993532 -4.2506037  -5.69127207]
# 2. x*(y-y_predicted)) =  [  0.07140142  -2.7385339   -8.42980597 -17.00241478 -28.45636034]
# 3. sum(x*(y-y_predicted))) =  -56.55571357202787
# 4. (-(2/n)*sum(x*(y-y_predicted))= 22.62228542881115
# theta1 =  1.6308855378034224
# ##########################################################################################
